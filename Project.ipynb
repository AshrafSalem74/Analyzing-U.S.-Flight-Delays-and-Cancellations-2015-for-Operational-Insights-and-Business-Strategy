# %%
#!pip install -r requirements.txt
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.6 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.6 MB 2.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.6 MB 2.5 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.6 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.6 MB 2.7 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.6 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.5/11.6 MB 2.9 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.6 MB 3.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.8/11.6 MB 2.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.6/11.6 MB 3.0 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
